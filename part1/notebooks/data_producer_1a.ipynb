# %%
#!pip install kafka-python

# %%
from kafka import KafkaConsumer, KafkaProducer
import json
import uuid
import pandas as pd
import csv
import time

# %% [markdown]
# # Data Producer 1

# %%
def connect_kafka_producer(servers):
    _producer = None
    try:
        _producer = KafkaProducer(bootstrap_servers=servers, api_version=(0, 10))
    except Exception as ex:
        print('Exception while connecting Kafka')
        print(str(ex))
    finally:
        return _producer

def publish_message(producer_instance, topic_name, key, value):
    try:
        key_bytes = bytes(key, encoding='utf-8')
        value_bytes = bytes(value, encoding='utf-8')
        producer_instance.send(topic_name, key=key_bytes, value=value_bytes)
        producer_instance.flush()
        print(f'Message published successfully to topic:  {topic_name}.')
    except Exception as ex:
        print('Exception in publishing message')
        print(str(ex))

def produce_xy(producer, topic_name, sleep_hz):
    with open('data/gen1_sinus_data.csv') as f:
        reader = [line.split() for line in f]
        for i, line in enumerate(reader):
            print(f'index {i}, data: {line}')
            message = json.dumps({'index':i, 'data': line})
            publish_message(producer, topic_name, str(uuid.uuid4()), message)
            time.sleep(sleep_hz)

# %%
server1 = 'broker1:9093'
server2 = 'broker2:9095'
server3 = 'broker3:9097'
topic = "data_gen1"

producer1 = connect_kafka_producer(server1)

hz = 0.5
produce_xy(producer1, topic, hz)
# Out:
# index 0, data: ['0']
# Message published successfully to topic:  data_gen1.
# index 1, data: ['0.0']
# Message published successfully to topic:  data_gen1.
# index 2, data: ['0.03947210874531593']
# Message published successfully to topic:  data_gen1.
# index 3, data: ['0.07888269410203015']
# Message published successfully to topic:  data_gen1.
# index 4, data: ['0.11817032857526096']
# Message published successfully to topic:  data_gen1.
# index 5, data: ['0.15727377630810155']
# Message published successfully to topic:  data_gen1.
# index 6, data: ['0.19613208852717737']
# Message published successfully to topic:  data_gen1.
# index 7, data: ['0.23468469854073934']
# Message published successfully to topic:  data_gen1.
# index 8, data: ['0.27287151614122407']
# Message published successfully to topic:  data_gen1.
# index 9, data: ['0.3106330212651392']
# Message published successfully to topic:  data_gen1.
# index 10, data: ['0.34791035676429133']
# Message published successfully to topic:  data_gen1.
# index 11, data: ['0.38464542014375824']
# Message published successfully to topic:  data_gen1.
# index 12, data: ['0.42078095412361627']
# Message published successfully to topic:  data_gen1.
# index 13, data: ['0.45626063588327037']
# Message published successfully to topic:  data_gen1.
# index 14, data: ['0.49102916484928394']
# Message published successfully to topic:  data_gen1.
# index 15, data: ['0.5250323488898789']
# Message published successfully to topic:  data_gen1.
# index 16, data: ['0.5582171887817576']
# Message published successfully to topic:  data_gen1.
# index 17, data: ['0.5905319608175923']
# Message published successfully to topic:  data_gen1.
# index 18, data: ['0.6219262974254254']
# Message published successfully to topic:  data_gen1.
# index 19, data: ['0.6523512656743241']
# Message published successfully to topic:  data_gen1.
# index 20, data: ['0.6817594435439233']
# Message published successfully to topic:  data_gen1.
# index 21, data: ['0.7101049938389817']
# Message published successfully to topic:  data_gen1.
# index 22, data: ['0.7373437356337428']
# Message published successfully to topic:  data_gen1.
# index 23, data: ['0.7634332131347431']
# Message published successfully to topic:  data_gen1.
# index 24, data: ['0.7883327618547351']
# Message published successfully to topic:  data_gen1.
# index 25, data: ['0.8120035719945818']
# Message published successfully to topic:  data_gen1.
# index 26, data: ['0.8344087489343345']
# Message published successfully to topic:  data_gen1.
# index 27, data: ['0.8555133707392045']
# Message published successfully to topic:  data_gen1.
# index 28, data: ['0.8752845425908038']
# Message published successfully to topic:  data_gen1.
# index 29, data: ['0.8936914480588065']
# Message published successfully to topic:  data_gen1.
# index 30, data: ['0.910705397133126']
# Message published successfully to topic:  data_gen1.
# index 31, data: ['0.9262998709417328']
# Message published successfully to topic:  data_gen1.
# index 32, data: ['0.9404505630844201']
# Message published successfully to topic:  data_gen1.
# index 33, data: ['0.9531354175180894']
# Message published successfully to topic:  data_gen1.
# index 34, data: ['0.9643346629345058']
# Message published successfully to topic:  data_gen1.
# index 35, data: ['0.9740308435769415']
# Message published successfully to topic:  data_gen1.
# index 36, data: ['0.9822088464476727']
# Message published successfully to topic:  data_gen1.
# index 37, data: ['0.9888559248639253']
# Message published successfully to topic:  data_gen1.
# index 38, data: ['0.9939617183255519']
# Message published successfully to topic:  data_gen1.
# index 39, data: ['0.9975182686634748']
# Message published successfully to topic:  data_gen1.
# index 40, data: ['0.9995200324437229']
# Message published successfully to topic:  data_gen1.
# index 41, data: ['0.999963889607732']
# Message published successfully to topic:  data_gen1.
# index 42, data: ['0.9988491483354384']
# Message published successfully to topic:  data_gen1.
# index 43, data: ['0.9961775461235876']
# Message published successfully to topic:  data_gen1.
# index 44, data: ['0.9919532470775769']
# Message published successfully to topic:  data_gen1.
# index 45, data: ['0.986182835421053']
# Message published successfully to topic:  data_gen1.
# index 46, data: ['0.9788753052333802']
# Message published successfully to topic:  data_gen1.
# index 47, data: ['0.9700420464309764']
# Message published successfully to topic:  data_gen1.
# index 48, data: ['0.9596968270143666']
# Message published successfully to topic:  data_gen1.
# index 49, data: ['0.9478557716086233']
# Message published successfully to topic:  data_gen1.
# index 50, data: ['0.9345373363306436']
# Message published successfully to topic:  data_gen1.
# index 51, data: ['0.9197622800224355']
# Message published successfully to topic:  data_gen1.
# index 52, data: ['0.9035536318952514']
# Message published successfully to topic:  data_gen1.
# index 53, data: ['0.8859366556349987']
# Message published successfully to topic:  data_gen1.
# index 54, data: ['0.8669388100248758']
# Message published successfully to topic:  data_gen1.
# index 55, data: ['0.8465897061466118']
# Message published successfully to topic:  data_gen1.
# index 56, data: ['0.8249210612270135']
# Message published successfully to topic:  data_gen1.
# index 57, data: ['0.8019666492017589']
# Message published successfully to topic:  data_gen1.
# index 58, data: ['0.7777622480734944']
# Message published successfully to topic:  data_gen1.
# index 59, data: ['0.7523455841462826']
# Message published successfully to topic:  data_gen1.
# index 60, data: ['0.7257562732233178']
# Message published successfully to topic:  data_gen1.
# index 61, data: ['0.6980357588595704']
# Message published successfully to topic:  data_gen1.
# index 62, data: ['0.6692272477655924']
# Message published successfully to topic:  data_gen1.
# index 63, data: ['0.6393756424631747']
# Message published successfully to topic:  data_gen1.
# index 64, data: ['0.60852747129782']
# Message published successfully to topic:  data_gen1.
# index 65, data: ['0.5767308159171155']
# Message published successfully to topic:  data_gen1.
# index 66, data: ['0.5440352363280496']
# Message published successfully to topic:  data_gen1.
# index 67, data: ['0.5104916936500697']
# Message published successfully to topic:  data_gen1.
# index 68, data: ['0.47615247068429345']
# Message published successfully to topic:  data_gen1.
# index 69, data: ['0.44107109042267656']
# Message published successfully to topic:  data_gen1.
# index 70, data: ['0.40530223262414466']
# Message published successfully to topic:  data_gen1.
# index 71, data: ['0.3689016485877325']
# Message published successfully to topic:  data_gen1.
# index 72, data: ['0.3319260742555569']
# Message published successfully to topic:  data_gen1.
# index 73, data: ['0.29443314178107305']
# Message published successfully to topic:  data_gen1.
# index 74, data: ['0.25648128970044654']
# Message published successfully to topic:  data_gen1.
# index 75, data: ['0.21812967184705312']
# Message published successfully to topic:  data_gen1.
# index 76, data: ['0.17943806515107721']
# Message published successfully to topic:  data_gen1.
# index 77, data: ['0.14046677646791736']
# Message published successfully to topic:  data_gen1.
# index 78, data: ['0.1012765485806216']
# Message published successfully to topic:  data_gen1.
# index 79, data: ['0.06192846552286182']
# Message published successfully to topic:  data_gen1.
# index 80, data: ['0.022483857370016878']
# Message published successfully to topic:  data_gen1.
# index 81, data: ['-0.016995795353241097']
# Message published successfully to topic:  data_gen1.
# index 82, data: ['-0.05644895749985223']
# Message published successfully to topic:  data_gen1.
# index 83, data: ['-0.09581413521242031']
# Message published successfully to topic:  data_gen1.
# index 84, data: ['-0.1350299717709034']
# Message published successfully to topic:  data_gen1.
# index 85, data: ['-0.17403534322655295']
# Message published successfully to topic:  data_gen1.
# index 86, data: ['-0.21276945367304673']
# Message published successfully to topic:  data_gen1.
# index 87, data: ['-0.2511719300063148']
# Message published successfully to topic:  data_gen1.
# index 88, data: ['-0.2891829160253631']
# Message published successfully to topic:  data_gen1.
# index 89, data: ['-0.32674316572742357']
# Message published successfully to topic:  data_gen1.
# index 90, data: ['-0.3637941356520162']
# Message published successfully to topic:  data_gen1.
# index 91, data: ['-0.4002780761299897']
# Message published successfully to topic:  data_gen1.
# index 92, data: ['-0.4361381212953163']
# Message published successfully to topic:  data_gen1.
# index 93, data: ['-0.47131837771934193']
# Message published successfully to topic:  data_gen1.
# index 94, data: ['-0.5057640115293427']
# Message published successfully to topic:  data_gen1.
# index 95, data: ['-0.5394213338755994']
# Message published successfully to topic:  data_gen1.
# index 96, data: ['-0.5722378846137764']
# Message published successfully to topic:  data_gen1.
# index 97, data: ['-0.6041625140721744']
# Message published successfully to topic:  data_gen1.
# index 98, data: ['-0.6351454627764056']
# Message published successfully to topic:  data_gen1.
# index 99, data: ['-0.6651384390072337']
# Message published successfully to topic:  data_gen1.
# index 100, data: ['-0.6940946940706927']
# Message published successfully to topic:  data_gen1.
# index 101, data: ['-0.7219690951631558']
# Message published successfully to topic:  data_gen1.
# index 102, data: ['-0.7487181957177949']
# Message published successfully to topic:  data_gen1.
# index 103, data: ['-0.7743003031227768']
# Message published successfully to topic:  data_gen1.
# index 104, data: ['-0.7986755437056478']
# Message published successfully to topic:  data_gen1.
# index 105, data: ['-0.8218059248826246']
# Message published successfully to topic:  data_gen1.
# index 106, data: ['-0.8436553943759122']
# Message published successfully to topic:  data_gen1.
# index 107, data: ['-0.8641898964067557']
# Message published successfully to topic:  data_gen1.
# index 108, data: ['-0.8833774247766444']
# Message published successfully to topic:  data_gen1.
# index 109, data: ['-0.9011880727539199']
# Message published successfully to topic:  data_gen1.
# index 110, data: ['-0.9175940796880471']
# Message published successfully to topic:  data_gen1.
# index 111, data: ['-0.932569874278883']
# Message published successfully to topic:  data_gen1.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [8], line 9
#       6 producer1 = connect_kafka_producer(server1)
#       8 hz = 0.5
# ----> 9 produce_xy(producer1, topic, hz)
#
# Cell In [3], line 29, in produce_xy(producer, topic_name, sleep_hz)
#      27 message = json.dumps({'index':i, 'data': line})
#      28 publish_message(producer, topic_name, str(uuid.uuid4()), message)
# ---> 29 time.sleep(sleep_hz)
#
# KeyboardInterrupt:
